# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import roc_auc_score

# %%
train = pd.read_csv("train.csv").drop(columns=['opened_position_qty ', 'closed_position_qty'])
test = pd.read_csv("test.csv").drop(columns=['opened_position_qty ', 'closed_position_qty'])
df = pd.concat([train,test],sort=False)

# %%
bid_cols = ['bid1','bid2', 'bid3', 'bid4', 'bid5']
bid_vol_cols = ['bid1vol', 'bid2vol', 'bid3vol', 'bid4vol', 'bid5vol']
ask_cols = ['ask1', 'ask2', 'ask3', 'ask4', 'ask5',]
ask_vol_cols = ['ask1vol','ask2vol', 'ask3vol', 'ask4vol', 'ask5vol']

group_cols = {"bid_cols":bid_cols,"bid_vol_cols":bid_vol_cols,"ask_cols":ask_cols,"ask_vol_cols":ask_vol_cols}

# %%
for group in group_cols.keys():
    df[f"{group}_max"] = df[group_cols[group]].max(axis=1)
    df[f"{group}_min"] = df[group_cols[group]].min(axis=1)
    df[f"{group}_spread"] = df[f"{group}_max"].div(df[f"{group}_min"])
    
df["last_price_div__mid"] = df["last_price"].div(df["mid"])
df["d_opn_intrst_div_trnsctd_qty"] = df["d_open_interest"].div(df["transacted_qty"])
df["d_opn_intrst_div_trnsctd_qty"] = df["d_opn_intrst_div_trnsctd_qty"].fillna(0)

# %%
train = df.loc[~df.y.isna()]
test = df.loc[df.y.isna()].drop(columns=['id', 'y'])

train_y = train.y
train_x = train.drop(columns=['id', 'y'])

TRAIN_SIZE = 500000
perm = np.random.permutation(len(train_x))

df_train = TensorDataset(torch.tensor(train_x.iloc[perm[:TRAIN_SIZE]].to_numpy()), torch.tensor(train_y.iloc[perm[:TRAIN_SIZE]].to_numpy()))

val_x = torch.tensor(train_x.iloc[perm[TRAIN_SIZE:]].to_numpy())
val_y = train_y.iloc[perm[TRAIN_SIZE:]].to_numpy(dtype='double')

# %%
model = nn.Sequential(  
    nn.Linear(38, 300),
    nn.PReLU(),
    nn.Linear(300, 300),
    nn.PReLU(),
    nn.Linear(300, 40),
    nn.PReLU(),
    nn.Linear(40, 1)
)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-6)
loss_fn = nn.BCEWithLogitsLoss()
train_loader = DataLoader(df_train, batch_size=128, shuffle=True)

for epoch in range(30):
    model.train()
    for i, (data, target) in enumerate(train_loader):
        optimizer.zero_grad()
        output = torch.squeeze(model(data.float()))
        loss = loss_fn(output, target.float())
        loss.backward()
        optimizer.step()

        if i % 55 == 0: print('.',end='')
    print('Train Epoch: %d  Loss: %.4f' % (epoch + 1,  loss.item()))

    # Validate
    model.eval()
    with torch.no_grad():
        print(model(val_x.float()))
        vscore = roc_auc_score(
                val_y,
                torch.sigmoid(torch.squeeze(model(val_x.float()))).numpy())
        
    # Track validation error each epoch
    print('Validation score: %.4f' % (vscore))
# Out:
# ........................................................................Train Epoch: 1  Loss: 0.6211
# tensor([[-0.6556],
#         [-0.7549],
#         [-0.8557],
#         ...,
#         [-0.8399],
#         [-0.5085],
#         [-0.6438]])
# Validation score: 0.5495
# ........................................................................Train Epoch: 2  Loss: 0.7286
# tensor([[-0.6235],
#         [-0.7381],
#         [-0.8626],
#         ...,
#         [-0.8003],
#         [-0.4767],
#         [-0.6259]])
# Validation score: 0.5610
# ........................................................................Train Epoch: 3  Loss: 0.6124
# tensor([[-0.4330],
#         [-0.5692],
#         [-0.7228],
#         ...,
#         [-0.6015],
#         [-0.2861],
#         [-0.4546]])
# Validation score: 0.5727
# ........................................................................Train Epoch: 4  Loss: 0.6105
# tensor([[-0.6110],
#         [-0.7692],
#         [-0.9499],
#         ...,
#         [-0.7778],
#         [-0.4750],
#         [-0.6662]])
# Validation score: 0.5812
# ........................................................................Train Epoch: 5  Loss: 0.6258
# tensor([[-0.4518],
#         [-0.6269],
#         [-0.8389],
#         ...,
#         [-0.6143],
#         [-0.3184],
#         [-0.5258]])
# Validation score: 0.5895
# ........................................................................Train Epoch: 6  Loss: 0.6112
# tensor([[-0.6290],
#         [-0.8249],
#         [-1.0615],
#         ...,
#         [-0.7924],
#         [-0.5089],
#         [-0.7312]])
# Validation score: 0.5948
# ........................................................................Train Epoch: 7  Loss: 0.6980
# tensor([[-0.1002],
#         [-0.3056],
#         [-0.5672],
#         ...,
#         [-0.2561],
#         [ 0.0244],
#         [-0.1869]])
# Validation score: 0.6011
# ........................................................................Train Epoch: 8  Loss: 0.7027
# tensor([[-0.1937],
#         [-0.4023],
#         [-0.6780],
#         ...,
#         [-0.3504],
#         [-0.0707],
#         [-0.2728]])
# Validation score: 0.6040
# ........................................................................Train Epoch: 9  Loss: 0.5717
# tensor([[-0.5649],
#         [-0.8090],
#         [-1.1145],
#         ...,
#         [-0.7265],
#         [-0.4749],
#         [-0.7062]])
# Validation score: 0.6058
# ........................................................................Train Epoch: 10  Loss: 0.6142
# tensor([[-0.7639],
#         [-1.0186],
#         [-1.3357],
#         ...,
#         [-0.9287],
#         [-0.6807],
#         [-0.9077]])
# Validation score: 0.6075
# ........................................................................Train Epoch: 11  Loss: 0.6399
# tensor([[-0.3274],
#         [-0.5829],
#         [-0.9215],
#         ...,
#         [-0.4873],
#         [-0.2377],
#         [-0.4487]])
# Validation score: 0.6107
# ........................................................................Train Epoch: 12  Loss: 0.7795
# tensor([[-0.6915],
#         [-0.9768],
#         [-1.3341],
#         ...,
#         [-0.8571],
#         [-0.6273],
#         [-0.8550]])
# Validation score: 0.6112
# ........................................................................Train Epoch: 13  Loss: 0.8153
# tensor([[-0.4342],
#         [-0.7334],
#         [-1.1209],
#         ...,
#         [-0.5972],
#         [-0.3822],
#         [-0.6107]])
# Validation score: 0.6129
# ........................................................................Train Epoch: 14  Loss: 0.6470
# tensor([[-0.3630],
#         [-0.6611],
#         [-1.0565],
#         ...,
#         [-0.5262],
#         [-0.2919],
#         [-0.5162]])
# Validation score: 0.6145
# ........................................................................Train Epoch: 15  Loss: 0.5998
# tensor([[-0.3153],
#         [-0.6186],
#         [-1.0287],
#         ...,
#         [-0.4789],
#         [-0.2234],
#         [-0.4675]])
# Validation score: 0.6156
# ........................................................................Train Epoch: 16  Loss: 0.7220
# tensor([[-0.6877],
#         [-1.0065],
#         [-1.4354],
#         ...,
#         [-0.8676],
#         [-0.6398],
#         [-0.8679]])
# Validation score: 0.6153
# ........................................................................Train Epoch: 17  Loss: 0.7312
# tensor([[-0.5196],
#         [-0.8595],
#         [-1.3056],
#         ...,
#         [-0.6886],
#         [-0.5047],
#         [-0.7097]])
# Validation score: 0.6163
# ........................................................................Train Epoch: 18  Loss: 0.7054
# tensor([[-0.5887],
#         [-0.9336],
#         [-1.3953],
#         ...,
#         [-0.7597],
#         [-0.5575],
#         [-0.7831]])
# Validation score: 0.6169
# ........................................................................Train Epoch: 19  Loss: 0.6547
# tensor([[-0.6291],
#         [-0.9910],
#         [-1.4677],
#         ...,
#         [-0.8016],
#         [-0.6365],
#         [-0.8386]])
# Validation score: 0.6171
# ........................................................................Train Epoch: 20  Loss: 0.6163
# tensor([[-0.1135],
#         [-0.4843],
#         [-0.9795],
#         ...,
#         [-0.2800],
#         [-0.0838],
#         [-0.3092]])
# Validation score: 0.6187
# ........................................................................Train Epoch: 21  Loss: 0.6688
# tensor([[-0.5474],
#         [-0.9190],
#         [-1.4246],
#         ...,
#         [-0.7205],
#         [-0.5582],
#         [-0.7562]])
# Validation score: 0.6182
# ........................................................................Train Epoch: 22  Loss: 0.5075
# tensor([[-0.5137],
#         [-0.8863],
#         [-1.4058],
#         ...,
#         [-0.6881],
#         [-0.5174],
#         [-0.7184]])
# Validation score: 0.6187
# ........................................................................Train Epoch: 23  Loss: 0.5658
# tensor([[-0.6945],
#         [-1.0982],
#         [-1.6373],
#         ...,
#         [-0.8708],
#         [-0.7398],
#         [-0.9426]])
# Validation score: 0.6182
# ........................................................................Train Epoch: 24  Loss: 0.5207
# tensor([[-0.6890],
#         [-1.1002],
#         [-1.6497],
#         ...,
#         [-0.8657],
#         [-0.7397],
#         [-0.9391]])
# Validation score: 0.6184
# ........................................................................Train Epoch: 25  Loss: 0.6275
# tensor([[-0.4270],
#         [-0.8203],
#         [-1.3734],
#         ...,
#         [-0.6327],
#         [-0.4152],
#         [-0.6394]])
# Validation score: 0.6200
# ........................................................................Train Epoch: 26  Loss: 0.6397
# tensor([[-0.8758],
#         [-1.3034],
#         [-1.8835],
#         ...,
#         [-1.0562],
#         [-0.9347],
#         [-1.1547]])
# Validation score: 0.6183
# ........................................................................Train Epoch: 27  Loss: 0.6671
# tensor([[-0.3505],
#         [-0.7556],
#         [-1.3366],
#         ...,
#         [-0.5292],
#         [-0.3837],
#         [-0.5657]])
# Validation score: 0.6202
# ........................................................................Train Epoch: 28  Loss: 0.6247
# tensor([[ 0.1238],
#         [-0.2909],
#         [-0.8839],
#         ...,
#         [-0.0448],
#         [ 0.1015],
#         [-0.0773]])
# Validation score: 0.6210
# ........................................................................Train Epoch: 29  Loss: 0.7853
# tensor([[-0.2675],
#         [-0.6990],
#         [-1.3006],
#         ...,
#         [-0.4419],
#         [-0.3103],
#         [-0.5007]])
# Validation score: 0.6206
# ........................................................................Train Epoch: 30  Loss: 0.6671
# tensor([[ 0.0329],
#         [-0.3837],
#         [-0.9966],
#         ...,
#         [-0.1710],
#         [ 0.0104],
#         [-0.1686]])
# Validation score: 0.6215

# %%
model.eval()
with torch.no_grad():
    test_x = torch.tensor(test.to_numpy())
    df_test = pd.read_csv('test.csv', index_col=0)
    df_test['Predicted'] = torch.sigmoid(torch.squeeze(model(test_x.float()))).numpy()
    df_test[['Predicted']].to_csv('submission.csv')
